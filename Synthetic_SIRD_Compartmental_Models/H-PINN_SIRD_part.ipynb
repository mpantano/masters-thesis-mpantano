# %% [markdown]
# # Attribute
#
# **Direct Reference**: pinn_ode_tutorial-master github repositor
#
# **Original Work**: *Renato Nascimento, Kajetan Fricke, Felipe Viana*
# **Reference Github repo** https://github.com/PML-UCF/pinn_ode_tutorial.git

# %% [markdown]
# # Libraries and Dependencies

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib as matplotlib

from torch.nn.parameter import Parameter
from torch import (
    linalg,
    nn,
    Tensor,
    stack,
    cat,
    transpose, 
    optim,
    zeros,
    diag,
    reshape,
    rand,
    tanh,
    mean,
    square
    )

#For Data Generation
from scipy import signal
from scipy import linalg as linalg2
from scipy.integrate import odeint

# %% [markdown]
# # Underlying Model and Training Dataset

# %%
def compartmentaldiff(y, t, beta, gamma, mu):
    S, I, D, R = y
    Sdot = - (beta / N) * S * I
    Idot = (beta / N) * S * I - gamma * I - mu * I
    Rdot = gamma * I
    Ddot = mu * I

    return Sdot, Idot, Ddot, Rdot

# %%
# Initial conditions
Ntrue = 59e6 #true population size
N = 1.0 #population size squished into 1 for ease of training
S0 = (Ntrue - 1)/Ntrue
I0 = N - S0
R0 = 0
D0 = 0
y0 = S0, I0, D0, R0

# A grid of time points (in days)
timesteps = 147
duration = 500
t = np.linspace(0, duration, timesteps)

# compartmental model parameters
beta_syn = 0.191
gamma_syn = 0.05
mu_syn = 0.0294

# Integrate the SIR equations over the time grid, t.
ret = odeint(compartmentaldiff, y0, t, args=(beta_syn, gamma_syn, mu_syn))
S, I, D, R = ret.T
S = np.reshape(S, (len(t), 1))
I = np.reshape(I, (len(t), 1))
D = np.reshape(D, (len(t), 1))
R = np.reshape(R, (len(t), 1))


#reshape time vector
t_data = np.transpose(t)
t_data = np.reshape(t_data, (len(t),1))

# keep clean data
Sc = S
Ic = I
Dc = D
Rc = R

#relative noise
noise = 0.05
S = (1 + noise * np.random.normal(0,1, S.shape)) * S
I = (1 + noise * np.random.normal(0,1, I.shape)) * I
D = (1 + noise * np.random.normal(0,1, D.shape)) * D
R = (1 + noise * np.random.normal(0,1, R.shape)) * R

# sample 50 evenly spaced data points
Strain = S[0:50]
Itrain = I[0:50]
Rtrain = R[0:50]
Dtrain = D[0:50]
ttrain = t[0:50]
print('debug')
# Out:
# debug

# %% [markdown]
# # Hybrid RNN Code

# %% [markdown]
# ### Construct / Deploy Hybrid RNN

# %%
class MyRNN(nn.Module):
    def __init__(self, cell, **kwargs):
        super(MyRNN, self).__init__()
        self.cell = cell

    def forward(self, inputs, initial_state):
        # Step into proceeding timestep
        bs, seq_sz, _ = inputs.shape
        state = []
        state.append(initial_state)
        for t in range(1, seq_sz): 
            input = inputs[:, t-1, :]
            state_t = self.cell.forward(input, state[t-1])
            state.append(state[t-1]+state_t)

        return stack((state),dim=1)

# %% [markdown]
# ### Construct Runge-Kutta Cell

# %%
class RungeKuttaIntegratorCell(nn.Module):
    def __init__(self, beta, gamma, mu, u, dt, **kwargs):
        super(RungeKuttaIntegratorCell, self).__init__(**kwargs)

        self.beta_param = Parameter(beta)
        self.gamma_param = Parameter(gamma)
        self.mu_param = Parameter(mu)
        
        # Runge-Kutta iterative vectors
        self.state_size   =  4
        self.A  = Tensor([0., 0.5, 0.5, 1.0])
        self.B  = Tensor([[1/6, 2/6, 2/6, 1/6]])
        self.dt = dt
        
     #force parameters to be in a range
    @property
    def beta(self):
        return tanh(abs(self.beta_param))

    @property
    def gamma(self):
        return tanh(abs(self.gamma_param))

    @property
    def mu(self):
        return tanh(abs(self.mu_param))

    def forward(self, inputs, states):
        y = states
        #Perform Runge-Kutta computation
        ydoti = self._fun(beta, gamma, mu, y)
        yi = y + self.A[0]*ydoti*self.dt
        fn = self._fun(beta, gamma, mu, yi)
        #Perfom Runge-Kutta Computation
        for j in range(1,4):
            yn = y + self.A[j] * ydoti * self.dt
            fn = cat([fn, self._fun(beta, gamma, mu, yn)], dim=0)

        y    = linalg.matmul(self.B, fn) * self.dt
        return y

    def _fun(self, beta, gamma, mu, y):
        Sdot = -self.beta*y[0,0]*y[0,1]
        Idot = self.beta*y[0,0]*y[0,1] - self.gamma*y[0,1] - self.mu*y[0,1]
        Rdot = self.gamma*y[0,1]
        Ddot = self.mu*y[0,1]
        ydot = cat(([Sdot,Idot,Rdot,Ddot]), dim = -1)
        ydot = reshape(ydot,(1,4))

        return ydot

# %% [markdown]
# ### Training Loop

# %%
def pinn_training_loop(n_epochs, optimizer, scheduler, model, loss_fn, train, label, initial_state):
    mae = nn.L1Loss()
    losses = []
    betas = []
    gammas = []
    mus = []
    for epoch in range(1, n_epochs + 1):
        #Forward pass
        output_train = model(train, initial_state)
        loss_train = (mean(square(output_train[0,:,1] - label[0,:,1])) + 
                        mean(square(output_train[0,:,3] - label[0,:,3])))
        mae_train = mae(output_train, label)
        losses.append(loss_train.item())
        betas.append(beta.item())
        gammas.append(gamma.item())
        mus.append(mu.item())
        #Backward pass
        optimizer.zero_grad()
        loss_train.backward()
        optimizer.step()
        scheduler.step()

        print(f"Epoch {epoch}, Training loss {loss_train.item():.4e}, mae {mae_train.item():.4e}")
        
    return losses, betas, gammas, mus

# %% [markdown]
# ### Execute Training

# %%
# initialize params randomly
beta = rand(1)
gamma = rand(1)
mu = rand(1)
print(tanh(abs(beta)))
print(tanh(abs(gamma)))
print(tanh(abs(mu)))

# data
dt = (t[1] - t[0])
t = Tensor(t)
Stense = Tensor(Strain)
Itense = Tensor(Itrain)
Rtense = Tensor(Rtrain)
Dtense = Tensor(Dtrain)
ytrain = cat(([Stense,Itense,Rtense,Dtense]),dim=1)
utrain = zeros(ytrain.size())
ufull =  zeros([1,147,4])
#resize tensors
t = reshape(t,(len(t),1))
utrain = reshape(utrain, (1, len(ttrain), 4))
ytrain = reshape(ytrain, (1, len(ttrain), 4))

# Initial state of the system 
initial_state = zeros(1,4)
initial_state[0,0] = y0[0]
initial_state[0,1] = y0[1]

rkCell = RungeKuttaIntegratorCell(beta = beta, gamma = gamma, mu = mu, u = utrain, dt=dt)
model = MyRNN(cell=rkCell)
''' 
#prediction results before training
yPred_before = model(ufull, initial_state)
yPred_before = yPred_before.detach().numpy()[0,:,:]
'''
#check number of params
total_params = sum(p.numel() for p in model.parameters())
print(total_params)

#PINN training
losses, betas, gammas, mus = pinn_training_loop(
        n_epochs = 1000,
        optimizer = optim.Adam(model.parameters(), lr=1e-2),
        scheduler = optim.lr_scheduler.CyclicLR(optim.Adam(model.parameters(), lr=1e-2), base_lr=1e-2, \
            max_lr=1e3, step_size_up=50, mode="exp_range", gamma=0.85, cycle_momentum=False),
        model = model,
        loss_fn = nn.MSELoss(),
        train = utrain,
        label = ytrain,
        initial_state=initial_state
        )
# Out:
# tensor([0.6061])
# tensor([0.3925])
# tensor([0.4787])
# 3
# Epoch 1, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 2, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 3, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 4, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 5, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 6, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 7, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 8, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 9, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 10, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 11, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 12, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 13, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 14, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 15, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 16, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 17, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 18, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 19, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 20, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 21, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 22, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 23, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 24, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 25, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 26, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 27, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 28, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 29, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 30, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 31, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 32, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 33, Training loss 7.8456e-03, mae 4.9284e-02
# Epoch 34, Training loss 7.8455e-03, mae 4.9284e-02
# Epoch 35, Training loss 7.8450e-03, mae 4.9281e-02
# Epoch 36, Training loss 7.8408e-03, mae 4.9263e-02
# Epoch 37, Training loss 7.8018e-03, mae 4.9120e-02
# Epoch 38, Training loss 7.4651e-03, mae 4.7970e-02
# Epoch 39, Training loss 6.0137e-03, mae 4.1232e-02
# Epoch 40, Training loss 6.2708e-03, mae 3.2735e-02
# Epoch 41, Training loss 6.1684e-03, mae 3.2599e-02
# Epoch 42, Training loss 5.4892e-03, mae 3.4218e-02
# Epoch 43, Training loss 5.9593e-03, mae 4.0834e-02
# Epoch 44, Training loss 6.0994e-03, mae 4.1806e-02
# Epoch 45, Training loss 5.6647e-03, mae 3.8113e-02
# Epoch 46, Training loss 5.5545e-03, mae 3.3137e-02
# Epoch 47, Training loss 5.9268e-03, mae 3.2388e-02
# Epoch 48, Training loss 5.7507e-03, mae 3.2461e-02
# Epoch 49, Training loss 5.4885e-03, mae 3.4361e-02
# Epoch 50, Training loss 5.6904e-03, mae 3.8401e-02
# Epoch 51, Training loss 5.7850e-03, mae 3.9370e-02
# Epoch 52, Training loss 5.5794e-03, mae 3.6944e-02
# Epoch 53, Training loss 5.5067e-03, mae 3.3612e-02
# Epoch 54, Training loss 5.6812e-03, mae 3.2586e-02
# Epoch 55, Training loss 5.6433e-03, mae 3.2676e-02
# Epoch 56, Training loss 5.4930e-03, mae 3.3914e-02
# Epoch 57, Training loss 5.5578e-03, mae 3.6588e-02
# Epoch 58, Training loss 5.6355e-03, mae 3.7758e-02
# Epoch 59, Training loss 5.5469e-03, mae 3.6398e-02
# Epoch 60, Training loss 5.4895e-03, mae 3.4016e-02
# Epoch 61, Training loss 5.5704e-03, mae 3.2996e-02
# Epoch 62, Training loss 5.5716e-03, mae 3.2986e-02
# Epoch 63, Training loss 5.4927e-03, mae 3.3861e-02
# Epoch 64, Training loss 5.5128e-03, mae 3.5691e-02
# Epoch 65, Training loss 5.5581e-03, mae 3.6625e-02
# Epoch 66, Training loss 5.5169e-03, mae 3.5809e-02
# Epoch 736, Training loss 3.9842e-05, mae 1.1412e-02
# Epoch 737, Training loss 3.9844e-05, mae 1.1410e-02
# Epoch 738, Training loss 3.9838e-05, mae 1.1417e-02
# Epoch 739, Training loss 3.9844e-05, mae 1.1420e-02
# Epoch 740, Training loss 3.9836e-05, mae 1.1413e-02
# Epoch 741, Training loss 3.9842e-05, mae 1.1407e-02
# Epoch 742, Training loss 3.9837e-05, mae 1.1410e-02
# Epoch 743, Training loss 3.9840e-05, mae 1.1415e-02
# Epoch 744, Training loss 3.9837e-05, mae 1.1413e-02
# Epoch 745, Training loss 3.9838e-05, mae 1.1406e-02
# Epoch 746, Training loss 3.9838e-05, mae 1.1405e-02
# Epoch 747, Training loss 3.9836e-05, mae 1.1410e-02
# Epoch 748, Training loss 3.9838e-05, mae 1.1411e-02
# Epoch 749, Training loss 3.9836e-05, mae 1.1406e-02
# Epoch 750, Training loss 3.9838e-05, mae 1.1403e-02
# Epoch 751, Training loss 3.9836e-05, mae 1.1405e-02
# Epoch 752, Training loss 3.9837e-05, mae 1.1408e-02
# Epoch 753, Training loss 3.9836e-05, mae 1.1406e-02
# Epoch 754, Training loss 3.9836e-05, mae 1.1402e-02
# Epoch 755, Training loss 3.9836e-05, mae 1.1402e-02
# Epoch 756, Training loss 3.9836e-05, mae 1.1405e-02
# Epoch 757, Training loss 3.9836e-05, mae 1.1406e-02
# Epoch 758, Training loss 3.9836e-05, mae 1.1403e-02
# Epoch 759, Training loss 3.9836e-05, mae 1.1401e-02
# Epoch 760, Training loss 3.9835e-05, mae 1.1403e-02
# Epoch 761, Training loss 3.9836e-05, mae 1.1404e-02
# Epoch 762, Training loss 3.9836e-05, mae 1.1403e-02
# Epoch 763, Training loss 3.9836e-05, mae 1.1401e-02
# Epoch 764, Training loss 3.9836e-05, mae 1.1401e-02
# Epoch 765, Training loss 3.9836e-05, mae 1.1403e-02
# Epoch 766, Training loss 3.9836e-05, mae 1.1404e-02
# Epoch 767, Training loss 3.9836e-05, mae 1.1402e-02
# Epoch 768, Training loss 3.9836e-05, mae 1.1401e-02
# Epoch 769, Training loss 3.9836e-05, mae 1.1403e-02
# Epoch 770, Training loss 3.9836e-05, mae 1.1404e-02
# Epoch 771, Training loss 3.9836e-05, mae 1.1403e-02
# Epoch 772, Training loss 3.9836e-05, mae 1.1402e-02
# Epoch 773, Training loss 3.9836e-05, mae 1.1402e-02
# Epoch 774, Training loss 3.9836e-05, mae 1.1404e-02
# Epoch 775, Training loss 3.9836e-05, mae 1.1404e-02
# Epoch 776, Training loss 3.9836e-05, mae 1.1402e-02
# Epoch 777, Training loss 3.9836e-05, mae 1.1402e-02
# Epoch 778, Training loss 3.9835e-05, mae 1.1404e-02
# Epoch 779, Training loss 3.9836e-05, mae 1.1404e-02
# Epoch 780, Training loss 3.9835e-05, mae 1.1403e-02
# Epoch 781, Training loss 3.9836e-05, mae 1.1403e-02
# Epoch 782, Training loss 3.9835e-05, mae 1.1404e-02
# Epoch 783, Training loss 3.9835e-05, mae 1.1404e-02
# Epoch 784, Training loss 3.9835e-05, mae 1.1404e-02
# Epoch 785, Training loss 3.9835e-05, mae 1.1403e-02
# Epoch 786, Training loss 3.9835e-05, mae 1.1404e-02
# Epoch 787, Training loss 3.9835e-05, mae 1.1404e-02
# Epoch 788, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 789, Training loss 3.9835e-05, mae 1.1404e-02
# Epoch 790, Training loss 3.9835e-05, mae 1.1404e-02
# Epoch 791, Training loss 3.9835e-05, mae 1.1404e-02
# Epoch 792, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 793, Training loss 3.9835e-05, mae 1.1404e-02
# Epoch 794, Training loss 3.9835e-05, mae 1.1404e-02
# Epoch 795, Training loss 3.9835e-05, mae 1.1404e-02
# Epoch 796, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 797, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 798, Training loss 3.9835e-05, mae 1.1404e-02
# Epoch 799, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 800, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 801, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 802, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 803, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 804, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 805, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 806, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 807, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 808, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 809, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 810, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 811, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 812, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 813, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 814, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 815, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 816, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 817, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 818, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 819, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 820, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 821, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 822, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 823, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 824, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 825, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 826, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 827, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 828, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 829, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 830, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 831, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 832, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 833, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 834, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 835, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 836, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 837, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 838, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 839, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 840, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 841, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 842, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 843, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 844, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 845, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 846, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 847, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 848, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 849, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 850, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 851, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 852, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 853, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 854, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 855, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 856, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 857, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 858, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 859, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 860, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 861, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 862, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 863, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 864, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 865, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 866, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 867, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 868, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 869, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 870, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 871, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 872, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 873, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 874, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 875, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 876, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 877, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 878, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 879, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 880, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 881, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 882, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 883, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 884, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 885, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 886, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 887, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 888, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 889, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 890, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 891, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 892, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 893, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 894, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 895, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 896, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 897, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 898, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 899, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 900, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 901, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 902, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 903, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 904, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 905, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 906, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 907, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 908, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 909, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 910, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 911, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 912, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 913, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 914, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 915, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 916, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 917, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 918, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 919, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 920, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 921, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 922, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 923, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 924, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 925, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 926, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 927, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 928, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 929, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 930, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 931, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 932, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 933, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 934, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 935, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 936, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 937, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 938, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 939, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 940, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 941, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 942, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 943, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 944, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 945, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 946, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 947, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 948, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 949, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 950, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 951, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 952, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 953, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 954, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 955, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 956, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 957, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 958, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 959, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 960, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 961, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 962, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 963, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 964, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 965, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 966, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 967, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 968, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 969, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 970, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 971, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 972, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 973, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 974, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 975, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 976, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 977, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 978, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 979, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 980, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 981, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 982, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 983, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 984, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 985, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 986, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 987, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 988, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 989, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 990, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 991, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 992, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 993, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 994, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 995, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 996, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 997, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 998, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 999, Training loss 3.9835e-05, mae 1.1405e-02
# Epoch 1000, Training loss 3.9835e-05, mae 1.1405e-02

# %% [markdown]
# ### Visualize Results

# %%
# constrained params
beta_con = np.tanh(betas)
gamma_con = np.tanh(gammas)
mu_con = np.tanh(mus)
beta_con = list(map(abs, beta_con))
gamma_con = list(map(abs, gamma_con))
mu_con = list(map(abs, mu_con))
print(beta_con[-1])
print(gamma_con[-1])
print(mu_con[-1])
ufull =  zeros([1,147,4])
#prediction results after training
yPred = model(ufull, initial_state) [0, :, :]
yPred = yPred.detach().numpy()

plt.plot(t, yPred[:,0], color = 'red', label = 'susceptible network', linestyle = 'dashed')
plt.plot(t, yPred[:,1], color = 'blue', label = 'infected network', linestyle = 'dashed')
plt.scatter(ttrain, Itrain, color = 'blue', label = 'infected')
plt.plot(t, yPred[:,3], color = 'black', label = 'dead network', linestyle = 'dashed')
plt.scatter(ttrain, Dtrain, color = 'black', label = 'dead')
plt.plot(t, yPred[:,2], color = 'green', label = 'recovered network', linestyle = 'dashed')
'''
#True values
plt.plot(t, Sc, color = 'red', label = 'susceptible true')
plt.plot(t, Ic, color = 'blue', label = 'infected true')
plt.plot(t, Dc, color = 'black', label = 'dead true')
plt.plot(t, Rc, color = 'green', label = 'recovered true')
'''
plt.legend()
#plt.title('Network recreation of training dataset')
plt.xlabel('Time [days]')
plt.ylabel('Fraction of population')
plt.show()

# Loss
plt.plot(losses,color = 'black')
plt.yscale("log")
#plt.title("Loss trend under Adam optimization")
plt.xlabel('Epochs')
plt.ylabel('Loss [base 10 log]')
plt.show()

# plot the learned SIRD parameters vs true SIRD parameters
plt.plot(beta_con[0:], color = 'teal', label ="beta")
plt.plot(gamma_con[0:], color = 'red', label="gamma")
plt.plot(mu_con[0:], color = 'green', label="mu")
plt.axhline(y = 0.191, color = 'teal', linestyle = 'dashed', label ="betagoal")
plt.axhline(y = 0.05, color = 'red', linestyle = 'dashed', label ="gammagoal")
plt.axhline(y = 0.0294, color = 'green', linestyle = 'dashed', label ="mugoal")
plt.legend()
#plt.title('Change in Parameter estimation')
plt.xlabel('Epochs')
plt.ylabel('Parameter value')
plt.show()
# Out:
# 0.19251989186636925
# 0.04892299483098175
# 0.03007248493094312
